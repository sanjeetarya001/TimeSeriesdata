# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjeetarya001/TimeSeriesdata/blob/main/Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Using plotly.express
import plotly.express as px

df = px.data.stocks()
fig = px.line(df, x='date', y="GOOG")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Using graph_objects
import plotly.graph_objects as go

import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

fig = go.Figure([go.Scatter(x=df['Date'], y=df['AAPL.High'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
hi deb,

Notebook for TFT, NBEATS, FFT is ready on my side.
each notebook has very similar steps only model is varying.
In case of NBEATS , with the same NBEATS model we can do multivariate and univariate analysis.
so there is no need to make different notebook for univariate case.
I am sending you the NBEATS_complete_Analysis file.

I have prepared the notebook using FFT. But after discussion with subhender, i get to know that wavelet and fourier are totally different things.

I read one paper which is using wavelet decompostion for extracting trend and seasonality then forcasting each component separately with model.
And then combining the both result for final total forecasting. So basically we can use wavelet method for feature extraction only.
whats your thought on it?


################################################################################################################################################
As an example for our notebook , I am using data with hour frequency means each row has 1 hour of difference with its previous row.
our task is to forecast price for electricity.

Target TimeSeries : we want to forecast values
Covariates TimeSeries: we are not interested in forecasting them but using as an input to help our model to do better forecasting.

DataSet :
TimeIndex , Target Timeseries( in our data it is price column) ,Covariates( all column other then target column we have total 9 time series)


NOTE: we are taking a cleaned data ,Zero mistakes. the initial Data cleaning and preprocessing is not shown in this file.
Most of the the function I am using are from Darts Library

General Steps Taken in Notbooks:

1. dataframe ---> Timeseries
every thing in darts uses timeseries only

2. Trend and Seasonality check
if you see closely our data has weakly seasonality

3. Covariates timeseries

4.Train/Validation/Test sets creation
we are using 72%/18%/10% for our use. I have no concrete idea about what is good split. please give suggestion

5.Scaling our data between 0 and 1

MODEL PART STARTS ( similar steps like in sci-kit learn library)

6. Model Instantiating : creating model object with some parameter set.

7. Model fit method : takes input for training and validation set (optional) for better fit

8. Model predict method : takes length for which we want to forecasts and takes series for which we want to forecast.

9. Checked the prediction results on validation set

10. Using Optuna for hyperparameter tunning

11. Got the new parameters from tuning. Now repeating step 6 , 7 with new paramaters.

12. Validation Set Analysis .( mape calculation)

13. Test Set Analysis.( mape calculation)

14. Out of Sample prediction: we don't have actual data mean we cannot have mape.

#################################################################################################################################################
